# %%
x = var('x')

# %%
y=function('y')(x)

# %%
eq = x^4 == y^2 + x^6

# %%
dy = diff(y, x)

# %%
sol = solve(diff(eq), dy)

# %%
sol
# Out:
# [diff(y(x), x) == -(3*x^5 - 2*x^3)/y(x)]

# %%
show(dy.subs(sol))
# Out:
# -(3*x^5 - 2*x^3)/y(x)

# %%
def solution(x,y): return -(3*x^5 - 2*x^3)/y

# %%
m = solution(-0.8, 0.384)

# %%
m
# Out:
# -0.106666666666667

# %%
tan = m*(x + 0.8) + 0.384

# %%
p = []

# %%
p.append(implicit_plot(f,(x,-1,1),(y, -1, 1), color='blue', title='f(x,y)'))

# %%
p.append(plot(tan,(x,-1,1), color='red', legend_label='tangent line at point (-0.8, 0.384)'))

# %%
sum(p)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
g(x) = sqrt(x^4 - x^6)

# %%
h(x) = -sqrt(x^4 - x^6)

# %%
q = []

# %%
q.append(plot(g(x),(x,-1,1), ymin=-1, ymax=1, color='blue', legend_label='g(x)'))

# %%
q.append(plot(h(x),(x,-1,1), ymin=-1, ymax=1, color='red', legend_label='h(x)'))

# %%
sum(q)
# Out:
# Graphics object consisting of 2 graphics primitives
